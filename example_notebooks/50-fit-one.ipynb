# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import skimage.io as skio
import skimage
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 150
import tifffile
import numpy as np
from utils import *
import os
from pathlib import Path
import trackpy as tp

# %%
#in_file = r"D:\data\2022-04-26_WALKER_DATA\AjasjaRollerData\25C_75mMNaCl_A8fibres\2B9\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_1.tif"
#in_file = r"D:\data\2022-04-26_WALKER_DATA\AjasjaRollerData\25C_75mMNaCl_A6fibres\2B9\2B9_singlemolecule_1nM_A6fibres_25C_75mMNaCl_1.tif"
#in_file = r"D:\data\2022-04-26_WALKER_DATA\AjasjaRollerData\37C_75mMNaCl_A6fibres\2B9\2B9_singlemolecule_1nM_A6fibres_37C_75mMNaCl_NoMC_4.tif"
in_file = r"D:\data\2022-04-26_WALKER_DATA\2021-09-27__prelim_data\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200.tif"
basename = os.path.basename(in_file)
out_dir = Path('./out/')
def take_only_walkers_on_fibre_trajectory(in_file, out_file=None):
    """Takes an input file or a stack in the form of TCYX and saves it to out file. Writes the shape of TYX"""
    
    if isinstance(in_file, str):
        #Could also be a path object, but that would now fail. pethaps change to file exists, or test if in_file is an array
        stack = skio.imread(in_file)
    else:
        stack = in_file
    
    dims = stack.shape
    #skip the channel?
    new_dims = (dims[0], dims[2], dims[3]) 
    out = np.zeros(new_dims, dtype=np.uint8)
    for i in range(dims[0]):
        frame_fibre=stack[i, 0, :, :]
        frame_walker=stack[i, 1, :, :]
        new = take_only_walkers_on_fibre(frame_fibre, frame_walker)
        out[i] = new

    tifffile.imwrite(out_file, out , ome=True, dtype=np.uint8, 
        photometric='minisblack', metadata={'axes': 'TYX'})


os.makedirs(out_dir, exist_ok=True)
take_only_walkers_on_fibre_trajectory(in_file, out_dir/basename)
basename_noext, ext = os.path.splitext(basename)

# %%
fit_method='lq'
box_side_length = 5
drift = 0
min_gradient = 600

# %%
os.environ['HDF5_DISABLE_VERSION_CHECK']='1'
#TOOD add out parameter
# !python -m picasso localize {out_dir/basename} --fit-method {fit_method} --box-side-length {box_side_length}  --gradient {min_gradient} --drift {drift}

#Hack -- for now just rename the out file. This is dangerous in multithreaded environment.
out_locs =  (out_dir / (basename_noext+'_locs.hdf5'))
new_suffix = f'__locs__fit_{fit_method}__box_{box_side_length}__gradient_{min_gradient}__drift_{drift}.hdf5'
new_suffix = f'__locs_{fit_method}_box{box_side_length}_grad{min_gradient}_drift{drift}.hdf5'
new_out_locs = (out_dir / (basename_noext+new_suffix))
print(new_out_locs)
out_locs.with_suffix('.yaml').rename(new_out_locs.with_suffix('.yaml'))
out_locs.rename(new_out_locs)
# Out:
#     ____  _____________   __________ ____ out\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200__locs_lq_box5_grad600_drift0.hdf5
#
#    / __ \/  _/ ____/   | / ___/ ___// __ \
#   / /_/ // // /   / /| | \__ \\__ \/ / / /
#  / _____/ // /___/ ___ |___/ ___/ / /_/ /
# /_/   /___/\____/_/  |_/____/____/\____/
#
# Localize - Parameters:
# No       Label           Value
# 1        command         localize
# 2        files           out\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200.tif
# 3        box_side_length 5
# 4        fit_method      lq
# 5        gradient        600
# 6        drift           0
# 7        baseline        0
# 8        sensitivity     1
# 9        gain            1
# 10       qe              1
# 11       mf              0
# 12       zc
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Processing out\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200.tif, File 1 of 1
# ------------------------------------------
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 10 of 101
# Identifying in frame 64 of 101
# Identifying in frame 101 of 101
# File saved to out\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200_locs.hdf5
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# Warning! ***HDF5 library version mismatched error***
# The HDF5 header files used to compile this application do not match
# the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation faults may occur if the application continues.
# This can happen when an application was compiled by one version of HDF5 but
# linked with a different version of static or shared HDF5 library.
# You should recompile the application or check your shared library related
# settings such as 'LD_LIBRARY_PATH'.
# 'HDF5_DISABLE_VERSION_CHECK' environment variable is set to 1, application will
# continue at your own risk.
# Headers are 1.10.6, library is 1.10.5
#         SUMMARY OF THE HDF5 CONFIGURATION
#         =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.5
#                   Configured on: 2019-03-04
#                   Configured by: Visual Studio 15 2017 Win64
#                     Host system: Windows-10.0.17763
#               Uname information: Windows
#                        Byte sex: little-endian
#              Installation point: C:/Program Files/HDF5
#
# Compiling Options:
# ------------------
#                      Build Mode:
#               Debugging Symbols:
#                         Asserts:
#                       Profiling:
#              Optimization Level:
#
# Linking Options:
# ----------------
#                       Libraries:
#   Statically Linked Executables: OFF
#                         LDFLAGS: /machine:x64
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:
#                 Extra libraries:
#                        Archiver:
#                          Ranlib:
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                        CPPFLAGS:
#                     H5_CPPFLAGS:
#                     AM_CPPFLAGS:
#                          CFLAGS:  /DWIN32 /D_WINDOWS /W3
#                       H5_CFLAGS:
#                       AM_CFLAGS:
#                Shared C Library: YES
#                Static C Library: YES
#
#                         Fortran: OFF
#                Fortran Compiler:
#                   Fortran Flags:
#                H5 Fortran Flags:
#                AM Fortran Flags:
#          Shared Fortran Library: YES
#          Static Fortran Library: YES
#
#                             C++: ON
#                    C++ Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                       C++ Flags: /DWIN32 /D_WINDOWS /W3 /GR /EHsc
#                    H5 C++ Flags:
#                    AM C++ Flags:
#              Shared C++ Library: YES
#              Static C++ Library: YES
#
#                             JAVA: OFF
#                    JAVA Compiler:
#
# Features:
# ---------
#                    Parallel HDF5: OFF
# Parallel Filtered Dataset Writes:
#               Large Parallel I/O:
#               High-level library: ON
#                     Threadsafety: OFF
#              Default API mapping: v110
#   With deprecated public symbols: ON
#           I/O filters (external):  DEFLATE DECODE ENCODE
#                              MPE:
#                       Direct VFD:
#                          dmalloc:
#   Packages w/ extra debug output:
#                      API Tracing: OFF
#             Using memory checker: OFF
#  Memory allocation sanity checks: OFF
#           Function Stack Tracing: OFF
#        Strict File Format Checks: OFF
#     Optimization Instrumentation:
#
#   0%|          | 0/900 [00:00<?, ?task/s]c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# c:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# Warning! ***HDF5 library version mismatched error***
# The HDF5 header files used to compile this application do not match
# the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation faults may occur if the application continues.
# This can happen when an application was compiled by one version of HDF5 but
# linked with a different version of static or shared HDF5 library.
# You should recompile the application or check your shared library related
# settings such as 'LD_LIBRARY_PATH'.
# 'HDF5_DISABLE_VERSION_CHECK' environment variable is set to 1, application will
# continue at your own risk.
# Headers are 1.10.6, library is 1.10.5
#         SUMMARY OF THE HDF5 CONFIGURATION
#         =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.5
#                   Configured on: 2019-03-04
#                   Configured by: Visual Studio 15 2017 Win64
#                     Host system: Windows-10.0.17763
#               Uname information: Windows
#                        Byte sex: little-endian
#              Installation point: C:/Program Files/HDF5
#
# Compiling Options:
# ------------------
#                      Build Mode:
#               Debugging Symbols:
#                         Asserts:
#                       Profiling:
#              Optimization Level:
#
# Linking Options:
# ----------------
#                       Libraries:
#   Statically Linked Executables: OFF
#                         LDFLAGS: /machine:x64
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:
#                 Extra libraries:
#                        Archiver:
#                          Ranlib:
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler:War C:/Progning! ***HDF5 librarry version mismatched error***am Files (x86)/Microsoft Visual Studio/2017
# /The HDF5WCommuarning! ***HDF5 library version mismatched error***
# The HDF5 header files used to nity/VC/Tools/MSVC/14.16.27023/bin/Hostx86/ cox6m4/chl.peaedielr xfilees t eh 19.i1us6s .ea2dp7 p0tl2oi7c. 1ation do not match
# the versi
#                        CPPFLAGS:
#                oco m n upil s ed eb  y the HtH5DhFis_ CPPFLAGS: a
# 5 p p ll i ibcra t io n  d aor yn otto  mwahticchh
#  tthhei s   a p p l  i c a t iAoMn_CPPFLve rsion useiAd by the HsG DSl:F 5
#   linked.
# Datai  brarc  oy r  rtu  Wp o    a twio h rich this apnpn  l iocat iing!o r  * n   i s   lCiFsegmentation faults may occur if the applicLnA**aGHkteSDid:.Fo5 library version mismatched er n
# /DD aWIN3tr2 /D_WINDOWS /W3
#                       H5_CFLAGS:
#               a corruption or segmentation fc     oor a un*tin*ues* lt.s
#
# TThihAe  MmHs_ cDCaaFn F5LAy happ oheadGeernc cwuhre ni faSn:    f
# t ai hppl el ai cae tpspli ic a u     ostednion    St oh aredcwo  Cnacso m cpile thiotimpsn Laiiulepbprlse.
# diacaT htriyon:i b y Yso Edno ceSn
#   ao vert ms n ha it   oa c n ppen h
#  owf Hh the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation Den af Fan 5u S latbtpsau tpitmlaic
# cayl it iCoon Likcn wcur ibefdas cra w rthe ayopiptl: imhpYilecatdE ia diff byeornSe n o
# tc o
# vnn                        Fortran: OFF
#                Fortran Compe version of HDF5 but
# linked with etrsai nidliuiefeosrfne: .r o
# e
# T hfn ts tviera tss c i c   o arion of static or shared HDF5 lin happb  e ns hwarrhen ed H aDF5 r   alniy .
#  WbYr aro a au pyr.
# Fp licnYsoaiohrttuonrian Fl ouagsnl g!s:whdo   ua*s
# *lc omrpid  led*r  eeb Hcy onocmom D eFpil  5e th  versilei oa p  i blr npe  tap  oflhicatHe HDF i55 Foor aybnut
# li po nrvpr ekrlticseratciion oadhre n  wFoiclcanthg khesm  youicas mat:ckhre d  dyour  i
# esr     rhso rh* aarefr*e df ld *eirent
#   b Tlvrehi e HaDrrb   AM FraFoysrrtyr related5 a nr
# elaheioted
# na settings such as 'LFDlsder _LIBRARY_ fePtAtaoilgTife ssnHg' sutsaetdsi .: cstuoch as
# com'pHiDl  'Fe5 _thi
# oLDDs I   _ SaLpIBApBlL R A R Y _ES_VhPiAErRTS catHIaOs'h.
# iared'orNH_DC FHenF5Ed o_C drDKHotra notDInF 5SLi libr 'AbBLE_VmatrcEahraR
# SItONyrhy_:CH  eEY.e CE
# nvKSY
# vei o'u   rsr esho nion v  o  iurmSnolnm dteeu annsrttteei  dccvv o aabmFrrypoii iraatltble erban il htseLeh  i esibH esrDat aFp sr5 ltiepto  y: b1liYtr,E S
# a
# or y     1 to whicac atp p   lh,i    i cata othion winlp olis a
# r c ppheccl       opkl iniyc t  inuc a C+our +teshaiaotionn w: ati lr yolu re
# iO dcsNo o
# wlnl niti  bin rrnk iaue sred.
# k  Dy.a a
# t trH  aelay eta o ecdu doer
# rr  srso eu w tpan ttr  iier no iCgns1+s k.+1 osu .0rc
# .ComsH6he agse,menp i latle'deartLrDsi a:i b_rCroLe:an f /IarP1BuyrogRl rA.t1ias0Rsm .Y6_,m aP yF1 AiTH .l1'o.el
# c0si'cH.uDbF5_5r
# D ISa r   r Aif theB (x86) yaL/E_V ppl  SM iiUcs icros1.10.5
# MEMARoSf RI O Y OF TN _Ct   aHtH iVE CSKUios'EMuMaAnlR Y    contiOSHeDFFt n5Tnuu HvedCE siOiHro.
# This can hDnom/eaF250N1F7Inptp ve n/GaC wheOriabnCUNl oRmFeaAmTunIIn ityOi sapGNU /s
# Rpel AViC/Tt cTaooI t iO N
# t lo o s/1  Mn,   =    wS VCa/p =1p4=l =ais .=c==c=o1a6=======.mt=====p2i==o=n==7= i=0=wled by===i 2=3l==/=ol=b==inn==
# /e====Hos= =c=ov=t==e=nxr
# =t8s
# =i6iG=n/on oueneraef HD= xat6 F=ly45= =o u=I/rnform==acl.ebt ixoew 1oun= =t=9nr.==
# i
# 1
# 6s:l
# Gke.ner
# .H-aela I2-7idn-0n-2f7oke-rs-e .-rda w-r-e-m-1-
#  i-1at h at i.- 10-d i  on:-
# ----f-.-6
# f , -e   r el ib   nr- ta -   ry    iv  s  -1-.-   - e 10. 5 -
#       C  r------- s i-+ +o
#    n    H oF DSUMl Ffa     gM5  sA:R  sVe/ Yt OFra  Dst TWii HIoc EN32   n  Ho:/ Dr D F 1_ 5s.W  h1IHCa0N.DOFrD5Oe5d
# H WVS N D/W3  Fe5 lF/rsiI GoRG /nEHsc
#  iU:  b  rR  ATION1a.r
# y.
# Y      1  0 o  . u   s         h5== ==ould=
#   ==        Confi == r e cog = H5ured m p C=+=+ Fla og=inle =:== = s :
# 2    0t 19-=0h3= - e=  0=  C4 ====a o
# ====== Wp = =  a
#
# Gen rp     nlei    c  i raa n   nA gtfMigurl!  ed  Ci o *+ +I*n* onforomn: a2rtH DFli0    o1n:a Fc5hec9 gs:k -03
# -   C l  yo0n4
#  - iofur-b
# irgu rsa      -h-ae  ---- rrded  libSyha-r     a vb- rey- ry relaete-rdsido- :Cn- m ++ L iV-is i
# busa-r---masrla t    St
# ue c h t dtiin y:  gConYs such ef igaod E    uerres ' Lr   dS bD   1 _
#        5 L IB y: Vis2      SRo r**u*0tAaRY_PAl
# 1TaTtH7 Win64 i hStH'
# .
#  c'uedDH   F5 VersioCH++Dn: 1.10.5
#  FDi F 5o_ D1I5L  S5 A      2 B         hiebara0 1dreyr   :     L YES E  7
#  f_iVERC o nSlIOWfiigur nN6
#  e  H4
#   _ed oCHECK' environment variable is set ts use   nosod  to c    1  ,o  :t am       ppl  s20p i      ly1i e s9c-0    a 3t -   tem: Windtihoin 0 owsws4 applill         J-10.0.
# A
# Hcontino1VA: i    st sys  Ocatti eum: on doW i not match
# the version u7esed by thnd aFF
#   t oew7 6 3
#  s-10      .HDF0   5 lib you  C . 1 ro7n7f6i3g
# ured by a          r         r o:  y  w  V n   is  r isutaJAVA  k ol Cw.ompi   U
#   lnSeH htreaaUiu:dincd mahe om rte e1sh   i5i
# sin
# Fanr2a0ppele 1a7f t1.f10.oroWrmimuiac6arnta,ti olni iibtres lai6soinon4:k:nr
#  e
# :y Wd-  is .-W-i-- ndowsi
# -
# --  n d-o
#  w1 .  Dsa
# t a 1 0     . c     5
#  o      r      r      u  Ho s        t    pti     o system:          PWindownS oa ra llU        re M MAl   Byt  Hs-1 DF5e: s0e. Rg  0OFFm s. eByentati1Y OF T7xt
# oH7:e lni6E tPtara l sl3f
# e Ha - eDu   lxF: 5elltl CONFIi Filtes may occerenGURAddian
#     u r   Dtatta TIOsle Nif tt e h
#      e  -  eU   nWdi a nrna
# p  i =a t pInm el=s tale= s  l : =ica  iatio=
# ntfo= n  r =  Imi =cnon aost= tnti= ion: = =pnWua== ies.
# Tol=lahi= ntis cadino no=ws  =ht
# :    appen nC    w: /     P=rog h=r====e Lp=oniaamr  n ge P=  atna a=======:p plFriC
# :
# /Giles Pacrlelnaotel /igoenI rrwas a l Informa/O: atHiomD Fnc: 5
#
# CFil
#  -o-oempsi/lH
#    e -m  DF-p-i 5   -d--     -
#
# C l ---biy noW a B mHipgho-n-erygt--in iOn-lein sg- g Oe!x:vlers peve-lionp  t*tof Hi*o-l
# iin sli o:Dbt   n
# s-:
#  rt----F   * --le-end-- ---i5 ary---- :   -Ha O butDn
#  -------
# -li-nkNF-
#   e d 5   -withlH     iD-b r a
# F-5-r-a  - y   V-      e rvsi-d-  o
# ieff    Inn:    e r er s    n 1  .  1t0.5
#  t  as   l l i  oanv  mt e  i sirosn      i  on  o mf       s   Bui     t a     But c h a    led tCipM Thrloode:oeadi
#  didntcsaf nM   efo  t:e Ciogrdre:ruory    s h ared on: 2      0r:ed HD1*9-DF5 lib0e/:*rary.
# Youb
# u *
# sTg 3  hhoPe  O FF
# gu lr   - d recompil  H Do04
#  ei t F 5 n h gramg      Deh eea bFiledSer     ymbolu s    g  f a / Hs: pi l espDl   Coniging fcation i   Deor FSym ch
# 5fbuols
# g
# ur :aCsed  e
# cebdy oku: Vim piy s lltt o coing Optm upailioo l eS thiur sh s    a nAP ptsaI  pu:r   ld
# emap i-c-a-i   pt-d-  i    oino---l in  -d1b r a-o    5g  nro------y related
#  -t:   set mv2-ting a0
# 1 1  t  ch1s  0
# 7theAss  su
# e  Wch arvienr s 6 s  ' 4   Wi t
# L    h  t   AD_LIBRA si: oR Y _     P sn
#  A      sderetsT H'    u.se
# d'p    HDF :
#  5 _  b      y   reca  t      H osh Beu tt e H  DdD pISAF i    5ubl B  L E s  Pir c lofillydi ibs_s ymnrtgVER:Se bol s Mod:e
#     m a: rPyr Win I OtOdN
#  :
#   o w   Noos -1 0f. i  0      _  l      i.17763
#      nCg     DH    I/         w:e EOCKO
#   phb uf t'g eiiicmizUlnterahg nvira  s (exitthion Letiersn mnoval):  DEFegnemea p pll  Sym:i
# icnfo
# naL rmabtt    o  ATEtl OvLp airioiiDtEanoWCaOsnbknir n:iliDnig meE n gO:i  W!pi
# zsati s Ei ndo* NtClo ns i  w* *OLevseHoDD e
# itn El Fnskteod:.:
#
#   5 1 ,
#  - lDib
# r--- a a
# Li- -- t    a-n--k-ir a   cnoyg  -  - -vrep p - -
#     r sl ic iO p t   orni    u   o n m a  spBi t i :ys m t
# t e   i -a-- A  ssertsstex:o :n  c   li- ho
# ot - --- r e n- w   dsegim e  - l lnt tl
# a te e -c on r i-o nt i----
#    n ureL-        e or*i     f*a u  a  n lMPt*
#  btrad  E syr T    imiha:oeuaen
#  Hs  y   o c      : D r  oc
# F   w u r5  iP
# r  n r  o  h  e a     fdilinISnsttfaliaskti  l . gc:
#     ata
# e  lhtei ornL  fHi le  aliyp e sbL  po  rarai   piend  luisc:i skeda t i e nE eo rn
# s d   t  : xt a OpCeccSutt:i/Ptraotic aom rcom b  aepnlteisnl ii zlae:ul 1o. gtrhaimseDtis1i.o rye0c
# . 6a,ntO  FFL  LpepvlTF
# h     iileil:c a
# t
#  inesi/ oVked l n   LExsedcFuHta i Db :DiFr5
# ar n k
# cCoo i nm
#    gb lOepst:in ot  oOFFpyin iss:
# a1
# nm     - -- .l a1    -i0.h    n5ga  pt
#   -pen w     ch - Optioe     h  L     -nDFL
#     n s:
# -AGS:  an t he- -    L DSU----a/ppmF-----laLcAGS-i-cat:i on wa---M-M---------
#               s ver
#    / mac c o shin      Bh i n  e : xi o6nA RYeu i4    OF
# m  :u     p xT HE is6e4d H
#    l dmla bye d     dlbl D    yoFt       5 M    on CONF e  versh e      o de:
#   c:
#   PacH D      HFIGURA    H5_L5 _   TDILk ageFDion 5oOFNLAf HDF5 bGLSA
# s  w/ G S:  :   uleib
#   r
#   Lx t   t
# lria    n   i    k barar er dy to  wd  =  heiesD= i c ebuwbit:=== uhg  = h  a gd g
# oii   thi=ng S s  a=y==== =p ffe=r =  S pml===t     e=a=ticanbt vu t putelrlyi:====   L  s=c===   AAaot
# i o====M nMl_Ls:_ =iDonF is
#  iL of stan     LAGS:
#  tked Ex ic or DFLAGS:e        cutabl       e
#       s :
# s  l i
# h  OF    E xtra aln kFri API     G
# eb ee neTr d      a    dr . r  ar    a l     c inInfH
# Dai    Dg:eo   F t sO:FF
#     5ar   E x  m a  tra
#      l t i l Aisse  cob rai  nr tsbo : r :  r
#  yrr U - -.a s
# ---
# r ie W  i  n g-a- run ing! *You should r-s--p*m*e  --- eHLc   -m:Dot  D-o F
#  i oF-L--     5A-Gn  om Sl
# i brr p: i  / rl     m a ea t  yc   r  y  sv e g heh r m ei e   A r chsaniocn imvet  h     r :
# pna t   pe ii e  l: soPc kerx n   fi:m6ra4oac  O
# F fat  F u   tHcDF l i on oi li n 5t
#  g:
# r     h es A M   d Vre e   c cre mm ha h    y   oi v sr  oee r:   rcic  r o roc
#      * u* *k   nr:
#           yy    1.  O  iaT o pHllocauRt15f_ trainlmiii0 .5L
# bz :a  Dohn s
# t h
#   eteio s  a FnLHan D   L  AaGF harn Spg 5 eiL:te   dpu laigey l
#  c hsev:i
# -  a cd a  eh ee-ct--lr  kfi -    isbl:e s  o -   uCrn-
# : o sae r
#  n d -yc ont  -L-ROi nueifnkin t
# o iFgFs a    u.r edc
#    n ron
#   gloibe: T h:m  lpate
#    Oidl2e
#  Lain
# ss et g0ua1g9ttpc eA-M_Lhtains hi in 0 Da og s3s-ap   F0LA4G
# p sp:uch     S
#  nls:i
# --p enc a-:  --a s   '
# t i  LD_-wo n     -h end    -F--     LoI----- -  a n  -  -- -a B   u-n-- R AR p-
#   C Yonfi     c _PA T  t gi urE oH n  e-xdn op-li
# c ' tt mra .   a    t
#  'tchS
#  tba lti heHDF5      veCra   b_ra:c k TrDaISAi on cyyie: w B nLEg_V Erieas:s ss:i R SI on     com puO F
#  i
# lOesFe d
#   dNV_    b yCi s     b y    Hu o  t  EaCKl    L '     in hCe  SbeSe:n  tr t  v  ravuHyi  i reirDrFocnds  5emtene    slibis
#     iroan ot    r:f
# o  F y HD F      15 2    v iS0lt1   t  7  W  ao ai e F otrn645r m aiA rc t Che   whci
# ah iC   lvieable b rc h  u :c
#  tish k s: t iC    C
# slso  O l F i m  F
#    y  n Cke ta ppo   tLpinkm poeliei     ildl   d1 c, ea r e p  w:  CrE:xOipt ipelactum i:tih oan dct   i /iaHtosziPsa bltfrCogr e    l:i/nsf: eOreki edP rnaoa n  om. F
# Datagtraiont FcorwR animr FuplFlie Itnsisl (sit
# bivlxyor :
# snulees 8t6em:r sc  o n( xm) /Mtioon
#  i i ro
# 8La6)nW indne/nMiccoguf t arwus as t  - greoieo 1oesss natsgot 0: oyofft . :muta V
# er t Vi -n------ otwnatsi- 0.1io
# ni-L-
# su a l rufD7 Sic oaF7L63ar tAs
# u l uGk l  sdS.
# t s i:  S/tmuHa macoy   och/e20 d i  a1c7ur  idhoe/iC om mfn er u a / s U r:2x60ntahre 1ienea a1t.yme pidpl17n4/VCi0ca.
#  / /t 6HD,fCi TF5 loormm io mouni bnr o tlyibcl s//MaSoV VC/TCnr/t oa1tar  o4lsiryy.i/nM SV
# .o16   is n.: uWY oC2/1e s i74u s. n 0 .h1 6d  2.3/2bi o  u
# ldThisonw/H1  . c a   s1 n  7 o 0s .
# 5
# hr0appt   2C3/:  y    xe s  e  b
#   encomip n 8  i/   6  lH   / weo S x h sHU M6 4 t5 eM/tcl. A  x_8en h     R  a Lx e 19.DY  6 n1 a O/FFLAp  xe66G   4 .pS T HEa2:pC / B7 02 cCy t
# 7l.opHl l1.eemi cati ps
#  Doini e  coxlexF5 art  :   lecr: C i hecik ot  C:you1t9l/ r s.OPNFI GURAn      h   1r6o a  T.27w red liaes  g0raIm-c    OFilo2m p eensbir adryNled7i an
#
#     ( by      .   ox 8 61  rel)n e=  /aM icCr tv=P
# o  ee=P s  dr=F= o
# s=L  f si=AA t eo=n M   Vi of t=ts_ HG=Si    D:Funa l= L
#  DF ===g=s=L5 I =StuA Gbut d   s=u=chn a i=S==
# sl 'LD= == = :o
#  = ==i=sta /=2=l nl0=
# k 17/
# Com  a_LIeB  tion  d     p oGmRu w i n    ien tA    n: Rth e  iY   rCa t  CP:P_y/VC/TooP l/F l s  InLaA /MSfHA5T PVroCgr odr/i_aEGxtS: mmHr1C
#  af'fe4.   ar l
# tion:
# ent' H P.P1iF-i D F F6Lbv5 _ .ArDG-SeaIrSiAr2l70e:BLEsise/ -
# -_  o sH:
#  2nVDF - 3oEf5 -   R S
#    / bi- -s tI
#  -    nOC omp /NHa   -osttiic -_x H5  ---8    ClHE6   -_iCo r sharned HD/          ----
#       x    PF 5 6 Pg  Opt4 /AlriFLAc CK'bArlc  enavMrhivie.exeGrS:
#    19.y16.
# _    . 27C:PPF 027 Y ou r
# LAGSis.1
#   :o
# h o ul   o       n  ds : n
#        r      -eco       H     mDF5 V      e    -m- rsi ----- o  p  AMn---------- e : 1.
# nit _ C l      variab 10.       5P CPP     l    eF e
# P  FLL   AiGA Sthe s  :s e      Ran Gatpp lication or check your  shl      t  S i b : :
#   a   o
#          1r C     e         F   Build
#    , Mad
#  L o Cp LpA    lldico   a ea:n
# n  f  i tgiuai gGS: o  bugnes  /DWIN3:r
# -  2  e  - w   d  -/-- roHn:D-_Wi   - - - C2019 l Fa5_CP I L -APFLr   DlN
# co0GeAbuyn3S-DGggin:
#     -OWS t/ g   S/D Wr einu elW:
# IS a30 N yat
#  3 2 my    /D4b o   _oW
# ut I NDOr  own We Sd  l s  r:
# /  i        s k
# W.sett  3
#    i n
#    gHead       e   s   r s         a r  s   e C :u c    1. 10         .Ah  6a s  'LD_M ye s
#  ,    L  I BRA _  C            li  CPPFLbR       Y   oArGSa:rnyfig  _ PATH      u'
# .  i  H5_  s    C
#  'HrF  1Asse L AG  d  H5S :  .D_F1
# bCFLAG  erts:Sy:: 0.5
#
# V
#       C Com 5 _DSIUSABLpil       e r: i su  E_VEa l  StR         CMMARS I   uCdiFLAGS:o 15    /D Y   O :W INOF THE H201/ P rDogr3 N7F am F _5   2i       les    CWC   / HiEn(    OCxD P   NK_r 6 8F6)Wo4fiIl/
#   'ing:
# I NGMUiRDA Ac T AMr OWS /W3
#           _ M env CFLAGS   _ C  :
#    oIF Lsi       o f  AH   t Vroo s  in tG S :OmNs s
#
# y e n    sute        m: Win     a l==   d t     o w  S tuds O   viH-S1=o/25 _CF=ptim a=ri0h.0.017/Co =aiLAGm1=7b7zmaS=h===t6Salae is :red i3sredu C  L
# =
# on n  =ity/VLet toCC L= =  e/ibr    v=el=:==Taools1=,==i=b ra   =r=y: Y   rapyE
# =   p:l YES      /
# MSS=
# = = ===i
#  Li=VC/  cn
# ki
# 1GeUantion  w   4 . illn
# aeme c o r al nn 16.inf og270trima tI2nf iOpon:o t  i o nr3  nsue:   W at
# /b in/ - ---mHA  i  yaoti   oMu_o-n:
# --CSsttxr8-6/n FS -x-a6t-oa-4-/tc-ticdLowAs
#  iwGS:-  c n  -rl .  C- - eC  L  ixiesk- - -
#    - - --1L
# i.b- 9b.1r6
#       .-27ra H -0 2a e a  7   d  r.r y:    -       Bey 1 -y-tr:  Y -s a E S
#
#  Ye -
# re  E 1S.
# - -
#
#        L S1 s     0 e  h ar.i 6,  le   i bxd C r a r       yb ir Li:  a r  b    is l1. 10 .r  e     5sittl
# a r       H:    eyD-F    CSP     eP5FL
#  n: Ve      AGS :d YES
# U
#  r iF M    Sao  st nM
#    a tic al      lAy R  i  or tr  Y L a       nn  i  :  :O n k  OF ed  F1F
#  E   .  T   1SHx     Fore   tEtcut0IHn5_ Ca  sPa. bHrtPt5 l DaFi
#  eaF5 LCc Cl nA: s :    OL iO FONb rG FlF
# at S F  i :FoIFG o nr
# U  R   a
# A       poir   T  n   I ytt     :r:  C:/ a     P n O   r o   Y  gN   EC or
#    S  a m m pFiloer
#  C Fril
# o t       :reasn   C o/  n
#      mA H   fMi   ==pgiu r e l=  _dD e=  C PF 5=    rL:DFLA
# =
# C P  F o
# GL Ao    =Gnm S  =S:p i:   :   l
# =  i n g    2 =Op / m0a c1t h  9 =i i  - =oFns:
# 0 3no  =F===r- -o e t -r= == ===t:-x04
# =r r    =a6n-  Fort: -   r  a n 4=
#   a   - -  FOl - n =   - -a=g== - --- =Fla s---= g :F-=
#   s F =
#
#
#  :
#
#        G       e  C     n   F L e    A ra  CG Hl   o   5   Sn f_I      i    L n:fo  DHg r  /FD LAG WuF m    IoSrtr  r B:5
#  aua N    tin3F2e d  l diH bo/ o5  yrDMn C o:_ o:m V WFdop iINDeilsurOtW trar
# ana ln S /:    F WS3-
# e
#   r : l- t    aF-u     g sdAMi : l ago-
#
#    -   s: _ -     L  DF
#   -  - -L1   -5  A   - 2 G   - 0 1S : -7
#   - - - -- -
#  D      A W      M   e i     Ab u    M  FF on g o rrt  g  ir   Ht5_ra   n6g4
# S a n F yCmb     F LAF o  olsn:r  GExt t r a n r S  lF
#  F laag sl:la:
#   a gi  g   s :
# s
#     b rar:            i
#    e s        :                          H o sSHDF
# 5   h  Ve r     s  i o  a   n  : t  sr 1.      Asser e H1y0s.t55 t deSm:h as
# :  W rFed i n       d Ao
#  o Mw_C   F osFrLAF o  - tGra 1  0 .0 rtrrn.    a  n  tran Fl  Library: Y1LibS:
#  7a 7 63 g       Es :
# r
# a      S
#     A rc          rhyi       P  Sh:     a r      C    vYoESnf ee
# i  g Sdta C  UAnaruredtme Liri: onM Foi
# c   onf:f     i oFor2lingbr tr019rtraarmaat rn:    y-03i
# on :L ib :-n Fla  04
#  rga r    sWyi      :  Y  E     nS  Y :Sdows
#     t
#         a   E
#      t i c F  S    o     R Con
#
#  r       tfrai    ang        u r n  lL i   ieb   S hbd:    a     Brred
#   Oypb
#   a  ty:  t S  Vri tLanFiysuaaeto:rl g  uasSmizatraetxYgesn  LtEiS
#
#  ibrcu  di:a
# C-    r--- o io 1L:n y-L: ibrary: YES
#
#        5 e Y - vlie    t2t01 -     7    E S - l-
#       e -l :  W
#   S-C +
# eLin    ntda+    kiian: OtNii
#
#    nc6
# 4
# n    Fo             F      o g  Oprtr       an        Ltibirary         o ns      :r    :  t    HC
# ra o st ---Y + +: - -  n :     EC++---s-O-O-F InstF
# ComNay  -p--i
# s  tle m S l  at-i-
#   l  e
#  orn:  pCo i
# :/P r   :  W       nt: C:i ogr a           Cm      / PF  :    irloenyes  s d
# g     o r F(x8 w a o 6 s -10 ) /  r. 0.17 m     7t 6  L Mr aF i  br3i
#      a n  Ciomr ielscp il  e  Ce: rso  r
# s/+H D    S+Fo   :t a Co   t f m pi t5     i
# Vi
#  ls c al leC ++  yur
#  :   C:  Unam C OCN
# e   o:mpil LaCl  i i/onki      e dPmrpil S  tnnef oog rru   g :md   E Oaitio/Fp tiox2 oor n 0 Ctes n  : Windo rc:1
# --:auram -/nt7w/CCoP aFsi+rFb-l
# m+oll-e s (gae-m urgs- nCoias:m mtpy/V--- ilerF-i-:xC8 6l :/ O)-/e
# sC :/   FF
# -P--r-o- T   g o  M
#  r( x i  o8 6)  a    c/ M i   l s/ rm  cM           FrSVC o s     i     Ho5l o  f Fe/s  t  Vio     s1 f(x8 6s) ut  Lo a l4 Vi   B.DsF/yMSruL ti1crosA t udaol S6t.raG S:2en F i o/ tlud/7masaei2fchigxo:/ 20s107/230tl it tB1 7//:l e
# VCiuC- bosnioe imue:xmn nm/H6m4
#  uodul a nsittdl  i y /Mnaitn
#   oSdy/V Cx e :/t86/V C
#  u d T   x i oo o ls /6/  /   2 4017  Too/lMc  s  /  l/.eSC  M x  eV S    o CA/ I m V  M m114. nstaC1 6. ulnla t 9i.1t6./i 2yF/Vo1 70223C7o Dretb4n 027.1/ point
# .brinan 1 6H5_LFDFlLu:gg/ Ho/. 2i ng Sa7gs: Cy:mboTl
#   s 0t2xA8 /  6oGo P /sx6:S : l43/cl.  S h/ b   a
#   i r reed   s/MxS e
#  nV/CHos o gr  t    a  F  / 1  o1 m  x9.1   C+8r6t F i  /ran+ 4  x L   .61liesb/rHar .62DFy6 7.F l:4 0257 a g 2 7./sc: / 1   0
# 2Y
# E
# 3l .e  ComDS    pxWe
#          /biI1N3 i   9A2Mnl i._ 1LDn   6 / Ass .   g  FH2 7SeOL/AG027poDsSr.tt_tWIx81a: tN6i
# t
# s / x  D: O W   i6S   o n
# sc  4:/
#  / W 3     c /  G R l Fo     . r-tr  e x/a     -CEPP  -nH  F  -Lsc
#  L A-e--- i b  - G r a1rE S :-y9:    -
#  -. Y    1 x t - --E   6 .2 70C +  S-r-+-
#  F
# l    a
# a2      li7  Profil. 1  b rar
#      g   i ng:      is
# :  / e s   D W I N      H 352    :               /       D
#           C +       +     H_5_CP   Bu    W iP  F  I ND O pl dO l aFMLA tgimWoS   s izat iond e/W:G :
# C +S
#     + :
#    CF      + l+ a    3L /  :   evelg s:G      R: O     /EHs  A/N
#  c           D
#
# r c hi
#       W L   v e     Iri   DN:n     32 /D e   k_  b
# iW  u    nIg g    N  O   D gp    AOiWtAHMM5 Ci o n g++   S  _nFs:  / l  C +SWa3 C +++
# C Py g -CommF s-:-pbio P FLAll s:
# G-Se   / :     G-Rr-
# l a
#     /gEHss - :  C:/P :  c - -
#  r
# og- --- r     - a     - m     -          F       iles
#                  R  A      M(  a    C ++  x  n     8  lFi  6   bS:      h )  /Al Mic saa
#  r  s gr     eHreo ss5td
#   L: sC:+ +     o ftCa+C
# F
#   n FLiL+ L l a gAgG V si:bu       ibsr r ar y : aSua
#  Y :r gaes:     /DWi  ElS
#   e  s:
#   -
#    I -     N  - ----3 S t S-Sh2  - a-P
# u r/Dr_ d Wo fe    i i  Ildingtati c : NoDOWS /W/      32
# 01 7 C++ /
# Co     a    L imlm     b r   uln a rA M y  yiSC L    t y+: t  /i+ F a  V lY    n Cka Opte/tg Ei dTis Sm  oc:
# i Eo
#  zxecC     luta b  s /+   Mles+            : LS  a t  O   H5_CV        S iiFFF C:obCL
# AShar/t a rye1t naeds GiS
#     c:r
#   L y            evel:  C C:+ Y
# E  4.16S
#   + Li.
#
#   b L2i + + Ln king i7 0   rar y:2 O        p      Cb ra3 /   YrAbinC EyM_CFotio: L     /  mSn  Hos ps YAtG
#
# :
# xS  E-- 8:6/ x-   S
#
# 6 i4    -  -    l e r:  C     /:LDF L -/Prograc    A      m F-l-  J A V .     iGS: /ma exA: OFF
#     les (x c --e 19.16----h           8 6ine     )./MiS :-2-
# 7 hxa64           red  027 .
#    S1
#       C   L    c tr os i     o batic C  rJaAV+    rfy+ Librt         Visual    Aa:     :r yS    J      YEAVA ComSt
#  u dpi   :   Yl eOr:
#
# F     iF FE
# L i  S  oe/b
#    2        H5rCar 0
#  +i_1  S a+e LDFLt7ustatic C :
# /F    r ClA LibStaticalommun rary: Ylayg eis GsS:Ety/VC/ToS
#
#  :
# -----:
#   L----
#     o     i nk     /les/MSVDWId          C / 1     Ex e4  .  N  1  c      Ju      A3V  6  t2 / D     ._2A a   7 W0 I    P            C2aNDOWSo m p   /W3bile srall3:A    e/ /GR JOFF
#    lbin/H/AVA: lo EM_LOs t H D ex 86sFF
#   F/LA    cH
#        D   xr64/F 5: :O   GForFt
#
# Scl.e xe:F
# P   ran a F ea
#    1 tur e     r:  O F Fa s  :   l 9
# -- l e.
#    l      JAVA Com         Extra librap- Filtered ri  1  6 ------
#        l er:. 270Data   2L  sie D
#
# Feat   e tures: s F
# 7- Writes::   H.1
#  L
# AG
#   -5   C           +    F +  S  ortF-la-g- -- - -r:a s
#     n :      Com
#   /   p  m                   i ler: a   P   Ac  a     hi r a   L
#   ne:a llel x 64   HDF  CP r 5
# : POFgF
# e Par al         rFLA    P arl e   G      S:
# l    c a l    Pa                  hiver:     Fo      I
#    rratr l e lan l/ O l HFl  e   a  lH 5:g
#   H_DLD    Fs:5A M  i _CPPF 5      l:
#   CFLAG F LAt eO   GSS:
#     :FF
# Par     r a       +llel F + e   i
#    d      l  tereF la    d Dga s Ratn a:
# l  i  D atsab  Higeh :  s -el      e  vt t  W r
#    H5
# La   F  n iguaog e  tAeeWsri M     s: _ LDF l
#  lt L :
# -rtran i-- AAG e--- SM:
#  -F-las : b_gs:-  -rar
# y: ON
#
#
#       S       C  PP    h FLA           a       G S:
#      E  L    r  ed        C + +x t      a     ra l Lib  i Lbara    r       rgrei ePsa:
# g rr       aaTrl     y e:  hrela ePardaYsE      aSl
#   lAfet y   l   : M OF       I     F / O F     CoFLrA : e  l
#     I tGS:   S  t at/ ra       n  C: /DWiF
#     Oy IcN3l:e   2C++s    a
#
#     g  LAD ef  i  b a s :r cu   r   /l ahiv Dt_ r e   W
#   rA PIy : H   N: YES    H I
# D miai g O gWSh-p
#
#    l  e vh    e / p  l- Wi    llievS     neh 3a r
#    bgl    er:     C  C ompa r   d ly  i  ler:   For: O N
# i  b rv C:    t / P      ar 1    r r   o y a1  g : n0  r
#   a O  N
#  m  F          WiL i    ti lR  hb  ea   r  snJHda r   A5Vy (  eA_:C x p:l  F r iY8E LeAOGbS6
#   T: c)SF h  a/:F
# r tM
# e
# Laad
#  eid ps a n    f   gStuabl   c  etuagresitc o s :i cTo f   symbt  hy
# --  Forols V i:-: rtrse a     -O-O- udFF
# -N-
# --a   a s af
#     e lty :  n  LS  O J    t u d     i      DeFiFo/2bfra A
# aru0V A  l  1  C ot7/C ym:pilo      eIr:    AP/      I       Y E m m
#
# muASO
#
#   an pDpfity  eiiFl/ Mfnteea _ aVrt C  gCsu Fu :/ r L l t   AGST(ools Avees /1MP I: S 1x
# :V C0tme-  :
#  arp-
#   yCnpal    Wi ) - / 1 : inth4 - --e.s  g : 1d6 -
#  e.2 - -        vp1r1
# 0D
#         C 7W0ieth E+ +c 2d :  a teFOL 3e/bpArS diNne/
# puH TcE aDtoe bEl id  Cc sh   O   tax DsE p 8 6/ rEu y x N b     ClO m6b      C4D e o i/E d  CCcco ml
# Plas: s ypmbrL ail o  blr   l.aeri l se:lO Hy x eN
#  :e 1rD FO5:N
#     :      9 .1C :   Y/O    6E.PFr     CFo
# Pgar+ 2   am+ SF  i7C
# ral  l o  l0e27.   le Fsi l(xI1I/O  8/6)tfil
# O fiet / Mim r  ltere r s ps i  celd  ((ex D at ter nr  e x t a s a l e e o) t rsnoe   :  DMrW:r aPl)E i f t:E t:  C F e   :
# Ls V  / A :SDt P i aET E  s
#     Dutrioc  E a CgCr lO  D am S EL FF t  i Li u Eb A l  NrCOTe   a dDs   riEoE
#      (   / D x y: 2 01  C P  L aY E8r6ge  7E)C/Mic   OPDE/DC PS rirea F Eocr LoNCOt
# aAGSD sV m:E
# oFl m
#
#  flelu ni t   ID/:  V  is   Ot:y
#      / V
#     C  /  u    T  a       l   o       St u           d  io/o      l  M PE: s / 2 017 M SV     C
# /1 4       H     . 16.2F7  Hi5/gCom_oCrPtP0 h  rmF2 -    uL3A/GbSi  a:n nl  n i /eH
#    ov: t  s e  y  t l l /VCx O   /8i bra  T6F/   o x  r  o F6
# y4: l    /   s / c O dNM lD.im Sa VMCP/E1 4 l
#   r e cte . l   x:  o   AM_CcVe1
#  P :F 61     D9.P.27 0:F
#  2 3/b L A 1i6.2G
# n7S        :   / 0 27.  H   1   o
# P
#     s ta c  F o  k  x 86/x6 r t a4  r          g     a /e s  n c     w            / lC  D    e o.Texxe mh  t i   rd1m rp er  9i.1la e aads   delealoc b fc6:   u e  . gt t yr2:
# o C 7P   PP:0u V aF L2tFD:cA
# 7 p uOk.a   tFg1
#  G:Fe
# CF L
#        A G S s S
# :
#  :         w        /   ext       r       a           /  d    D WIe     N 32      b  FD   u/dgma e D o l  _ r f l oW Ia o tu tupcrN  u t: aD  l t nO
#  A WP   A: I    P I
#    FClag HS    sP5+/ m:a
#  +W 3 c kag  _ Flae
# s   agppC wP/ si n T r: /g D e PW Ia  :F Nxc   L 3ti  vA 2rn  1G  ag      / :d O D1Se:
#   _ W   A0 I F  P bI  F
# HN  Tr  u5D OW g
# FaS    o ocrtWu  i ria t n/gnt  p:W hF  u 3  ld  O F Fa
# tg: e p /G    r  e
#    Rs :      H
#  AMc/a    _  CP   Et e U5H_sPFLs in  d  C g m c
#    Apubli F L  e mGoAc     rUsin  S :
#    sG S:y   AM
# g me ch e mor c    y               k   y  cehec m b  k  ro F er: OFFo         l   APH 5 C rItr:a
#     nTO FF
# + rF l a gsM em+a:   o  rcM em o  i ng :C s  yFl  :r Faags O N
# OlFFlL y a:
# o c   A
# a   l
#   t   G S :i     A  on l o/    Mc at s a nD _ CF iWo    i n I / I Sh    sanity checkty c LaO    h ered FN c UAGS:3fs    kAsi:
#   Mo  lOtersr2       s :/CD_WFi (exte FO
# FFIrNDn
# n +ta   g O +     Shla  Fmlr)eWran  :   DaLib rS E  arydgFLAe m o  T:    /WEsYr  F3
# :E S
#  F un
#  ctio       uyC Dn n  cLiECODE    Stheck   cabe    EtNr ar Crion Sc O: ytk D    : STrtac  EY
# aact OE i ni c FkgFSF
#
#  o r t  :Tracing: r aSn    OhOL             airbF     erar FF   Fy: Y
#
#      Me       Std  C mrSic  Sto       tt File ratic  F y all+     Co L+   r mi   H5Erict M_PEbLribrary:aaSC:o c
#
# F
#  iry:  a ttF LlYeE YAGS: ForEiSoSCm
# n
# h a
#
#  e ct sanity   Ch k        s  :e       cche ck s k  s:   :     O F      F
# O F      Opti           S mO F t   F    a
#  Fiti      AM_
# c    CCF++   L     z A       a G L i     Functi  tOS oip     nt :S toimF   bn  i
# o rrary   D  z:atira t  rYEIcns aS
#
#      ionCt++nk Ter: O:  IOFFNr nustm
# catc r
# V     i FuD  e nt:
# n     a t m   g :  e i  SO   o n:
#     har   F F    netadt C
#  L     i i o  b rn    aFr:  C
# +o r +   t Co mpr    y  : YES
#  ile        Sr     t:rict F  C:aile /     n P F   r Co JdAomaVrma l   to mp gCrhe l oc: i
#  le A   Paac:m Or :StFcFk
# k a   asge:F  i
#   l     sO t  F Fi e s
# c     C      w(   Li/x 8 b  6 )/     rOary: Yp ti E   mFiza e StMJxotrriA
# itraV
# a   Aoc r   d Cen   oboFsofunl agtm gs: Ip  Vinisltrum
# e r: s
# u e  n
# aoFle  Stuu t     t atdaturieputs:o:    n
# :
#  i
#  -------      o-/     H -
#       5   2F orF 017/t  orC om m a  unit n: OFFr
# yt   /VC/Tran    Paralle     l HDFol F5: O o l  F  a F
#  P  s/MSA  ForPVC/14.agraIlletsra1 6.nl  FTra2i7lc:C o
#  0i2    nmg: Op3tereiler :/ bi F dn /HoF
#  st
#      Datase    t W  AM   rx Foi 8 r      6 t  et/rx       F6Using4ortranas:
#  n/ Fcla   mFlages g s ::
# l.exe   m  o
# 1  9r y  ch ec       .16.27 ker: OFF
#      Shar    e Me0 d m o  2  H57r  Fo.1
# Frorty allocatiotr n raa   nnL  L a r sig aFbe nlr  iaaP      tgyary: Yrs:
#  aES
#   l         ch  le   ec    l   k  s     AM S t IF/O:
# a:C+to O + rFtF
#   r a n      Fl  Fa  lags:
#          Sg haredi cs    Fo H : irFor    g/DWtFrtIranhNa -ul3Libevnelr2  /acrtyn:lDi b iLr_YoiaWEnS S
# brIt
# ackNry:  Da O r TONyr:a  Wc
# i Sn g    : Y/W   ES
# O3  F        /     G FR /E
#      H    s    c S
#  t    a     t TSi  h     rc   tF e ro a ict  r d  tFs   ra  iale    Ffnety:  o  CH+5L +Or:CmF iONb
# r a+t+a    FFrlayC g:
# h ec    k   s  :   Y  E S
# s
#
#  :                                    CD    +e O f   FF
#  +   a     uC  l o Ot m ptimp   ii CA++:  lAeOPN
# Mz r I  :Cation+m   + F a p I Cpl in:ga :n v1/gPs      s10
#   :trum    W
# ite rogrntation:
# h   daC em+ +  Fp ile C  so r m( exp c8i at6 eSl)de/hM raprui: ecbrlioCdcs s: yo/PrmfboCo++ lgtr Laim sbVFrarilis: eyuas (xO:86)/Nl
#    MiStudiYcrosoft ViE S    o/201s
# u   a7/Com l   SmIut/uO fdniiti o/y /Vl         C2/0tTe1Soolstrs (ex7//CMatoerSnmtmaVl):  DEFLATuic C+En DiCECODEt+y  /LVC/To/ENCO1oibrary: 4lD.16.2sE/MSV7Y0ES
# 2C
#
# /14.    3 /    1 6 b . 27 in/Host    0    23/  bix86/x      6 4 n / /Hostx cl.ex8 6/    xe 19. 6   4 /1c   l6JAVA..2 :e xOFeF7
# 02 7.1
#              1 9  .   1      6.27027. MPE:
#  1
#                             J   A          V      A   C    o mpi      Di      rCecl+er: tC++ Flags: /DWI+
#  N
# FVl3a2FD: Fg/s :eat
# D   _ u/W rDI eWIN N 3s2DOWS  :
# //W3 /- DG_W-R ---- I -  N /-   -D
#  EO W SH s /W3      c d
# / m allG R  o  c : /   E
#   H s  c  P
#  a   c   k   aPg    ea rs  a   lwle  l /   HDF5 e:   O   H5 F xCFt +r
#  +aP   a FdrHale5lal bgeCus:
# gl    Fo +iu+ lt  tpeF u rl e  tda: gDs:a
#    t   as e
#      A Mt C++     W riF  tels :ag    s:
#
#                                     A   P     S h aA rLaIMr Trac gieCe Pa+drn+ ag Cllel I/O:F+la+ : gsO Libra
#    :
#  Fr       y :    Y F    E  S
#
#     Hig    S h tSa- htl aire ecv el d  C li+Cb + L  Usinri+ag merbmr+ory a Libryy:checker: OFF
# r a:r YES Memo
# y
# :   r yY   OE Nallocation sanit
#  yS
#              Static C+  + Libra   ryc      hecks: OFF
#           Function Stack Tracing: OFF
#        Strict File Format Checks: OFF
#    :     Y O  ptim  E  i  S
#
# z a   tio  n  T   h rI nest   a  rdus  amf   ee   tn t atJy i:o OFA VA: OFF
#                    JAVA Compiler                 JAVA: OFF
#                    JAVA Compiler:
#
# Features:
# ---------
#                    Parallel HDF5: OFF
# Parallel Filtered Dataset Writes:
#               Large Paral:F l n:
# e
#
#
# Featul  rI/O:
#         e      s   :
#   - - -H--i g  D-efauh-lt API ---m
# la   p evel lip bi n  rg a :r  v1 10
#  y:  O  With      Parallel HdepDFrecaNt5: OFF
# Paraed public syml
# lbo e l ls  Fi l:   t eO Nr
#  e d   D   a tas et  Wri  tes :
#    I/O filters (external):  DEFLATE DECODE ENCODE
#                              MPE:
#                       Direct VFD:
#                          dmalloc:
#   Packages w/ extra debug  output:
#                             La        API Tr rTahgceirne Parga: OFF
#             Using memory checker: OFF
#  Memory allocation sanity checlkadlsel saI:f/ eOtyO::F  F
# O
#  F  F
#                     Fu  n c   ti  Def ao u  Hilngth-  API lSmetavapecpk Trilna clg: ivng:i1 b10OrF
# aryF : W iOtNh
#
#       d    Strict File Format Checks: OFF
#     Optimization e p  I n restrum ce a n t    ate t di   pThoubrnea:l i
# dsafety: OFF
#              Default API mc syambopls:p inONg
# :       v   1 1I/O0
#   fWiltietrsh  d(eepxrterencataeld) p: u bDlEiFcL ATEs yDECOmDbolEs ENCO:D E
# ON
#             I/O       filters (external):  D E F LA T  E   D  EC O   D  E  EN CODE
#                  M P E :
#                       M PE :
#                             Dir e ct DViFrDec:
#                          dmalloc:
# t VFD:
#            P ac     kage   s w/ extra debug output:
#                      API Tracing: OFF
#             Using memor y c      dmalloc:
#   Packages w/ exthecker: Ora debug output:
#                    F  AFP
# I  MTermoacinryg a:ll OFF
# o            Using memory checkcation saniter: OFF
#  Memory allocation sanity checks: OFF
#           Function Stack Tracing: OFF
#      y checks:  Strict File  OFFFo
# r  m a t  Chec    k sFunctio:n OFF
# S t a c kOpt iTmization Instrumentation:
# racing: OFF
#        Strict File Format Checks: OFF
#     Optimization Instrumentation:
#
#   0%|          | 1/900 [00:16<4:04:01, 16.29s/task]
#  14%|█▎        | 123/900 [00:16<2:27:38, 11.40s/task]
#  35%|███▌      | 319/900 [00:16<1:17:16,  7.98s/task]
#  58%|█████▊    | 520/900 [00:16<35:22,  5.59s/task]
#  81%|████████  | 731/900 [00:16<11:00,  3.91s/task]
# 100%|██████████| 900/900 [00:16<00:00, 53.68task/s]
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# d:\data\2022-04-26_WALKER_DATA\2022-04-26__analysis\50-fit-one.ipynb Cell 4' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000004?line=8'>9</a> new_out_locs = (out_dir / (basename_noext+new_suffix))
#      <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000004?line=9'>10</a> print(new_out_locs)
# ---> <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000004?line=10'>11</a> out_locs.with_suffix('.yaml').rename(new_out_locs.with_suffix('.yaml'))
#      <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000004?line=11'>12</a> out_locs.rename(new_out_locs)
#
# File c:\bin\python\anaconda64\envs\picasso\lib\pathlib.py:1358, in Path.rename(self, target)
#    <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/pathlib.py?line=1355'>1356</a> if self._closed:
#    <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/pathlib.py?line=1356'>1357</a>     self._raise_closed()
# -> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/pathlib.py?line=1357'>1358</a> self._accessor.rename(self, target)
#    <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/pathlib.py?line=1358'>1359</a> return self.__class__(target)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'out\\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200_locs.yaml' -> 'out\\2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200__locs_lq_box5_grad600_drift0.yaml'

# %%
max_link_displacement_px = 2
min_tray_length = 3

# %%
new_out_locs
# Out:
# WindowsPath('out/2B9_SingleMolecule_1nM_A8fibres_25C_75mMNaCl_100-200__locs_lq_box5_grad600_drift0.hdf5')

# %%
for max_link_displacement_px in [1]:    
    locs = pd.read_hdf(new_out_locs, 'locs')
    locs['mass']=locs.photons



    tray = tp.link(locs, max_link_displacement_px)

    #count the length of trajectories
    tray_by_particle = tray.groupby(['particle'])
    tray['length'] = tray_by_particle['particle'].transform('count')

    #tray.length.hist()
    print("mean drift ", tp.compute_drift(tray).mean())


    #Exclude very short trays
    tray = tray.query(f'length>={min_tray_length}')

    steps = tray.groupby(['particle']).apply(get_steps_from_df)
    steps['step_len'] = np.sqrt(steps.dx**2+steps.dy**2)
    print(len(steps))

    suffix = f'__link{max_link_displacement_px}_traylen{min_tray_length}'
    base_linked_tray = Path(f'{new_out_locs.with_suffix("")}{suffix}')
    tray_out = base_linked_tray.with_suffix('.tray.csv.gz')
    tray.to_csv(tray_out)
    steps_out = base_linked_tray.with_suffix('.steps.csv.gz')
    steps.to_csv(steps_out)

    fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(5,15)  )

    plt.sca(axes[0])
    tray.length.hist()
    plt.xlabel('Trajectory Length')
    plt.title('Histogram of trajectory steps')

    plt.sca(axes[1])
    steps.plot.scatter('dx','dy', ax=axes[1])
    plt.title('Size of steps')

    plt.sca(axes[2])
    import numpy as np
    import scipy
    from scipy.stats import norm
    import matplotlib.pyplot as plt

    step_len_signed=steps.step_len*np.random.choice((-1,1), size=len(steps)) 
    # Generate some data for this demonstration.
    data = step_len_signed

    # Fit a normal distribution to the data:
    mu, std = norm.fit(data)
    print("Diff: ",std**2/2)

    # Plot the histogram.
    plt.hist(data, bins=15, density=True, alpha=0.6, color='g')

    # Plot the PDF.
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)

    plt.title(title)



    #perform Anderson-Darling Test 
    from scipy.stats import anderson
    anderson_data = anderson(data)

    is_normal = anderson_data.statistic<anderson_data.critical_values[1]
    if not is_normal:
        normal_str = f'NOT NORMAL AT {anderson_data.significance_level[1]}%'
    else:
        normal_str = f'normal at {anderson_data.significance_level[1]}%'
    print(normal_str)
    plt.xlabel('Step size (px)\n'+normal_str)
    plt.savefig(base_linked_tray.with_suffix('.png'))


    info = {}
    info['diff_1D_px_px_frame'] = float(get_diff_from_steps(steps))
    print("Diff (in px^2/frame): ", info['diff_1D_px_px_frame'] )

    px_to_nm = 110
    frame_to_s = 0.665

    info['diff_1D_nm_nm_s'] = info['diff_1D_px_px_frame'] *px_to_nm*px_to_nm/frame_to_s
    print("Diff (in nm^2/s): ", info['diff_1D_nm_nm_s'] )
    info['time_per_1000nm_s'] = 1000*1000/info['diff_1D_nm_nm_s']/2
    print("time per 1000nm (s): ", info['time_per_1000nm_s'])

    info['mean_step_nm_s']= float(np.sqrt(2*info['diff_1D_nm_nm_s']*frame_to_s)/frame_to_s)
    print("mean step (nm/s):",  info['mean_step_nm_s'])


    diff_info_out = base_linked_tray.with_suffix('.diff')

    info['normality_str'] = normal_str
    info['anderson_test'] = anderson_data

    write_yaml(info, diff_info_out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\data\2022-04-26_WALKER_DATA\2022-04-26__analysis\50-fit-one.ipynb Cell 7' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000006?line=1'>2</a> locs = pd.read_hdf(new_out_locs, 'locs')
#       <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000006?line=2'>3</a> locs['mass']=locs.photons
# ----> <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000006?line=6'>7</a> tray = tp.link(locs, max_link_displacement_px)
#       <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000006?line=8'>9</a> #count the length of trajectories
#      <a href='vscode-notebook-cell:/d%3A/data/2022-04-26_WALKER_DATA/2022-04-26__analysis/50-fit-one.ipynb#ch0000006?line=9'>10</a> tray_by_particle = tray.groupby(['particle'])
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\linking.py:188, in link(f, search_range, pos_columns, t_column, **kwargs)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=185'>186</a> coords_iter = coords_from_df(f, pos_columns, t_column)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=186'>187</a> ids = []
# --> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=187'>188</a> for i, _ids in link_iter(coords_iter, search_range, **kwargs):
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=188'>189</a>     ids.extend(_ids)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=190'>191</a> f['particle'] = ids
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\linking.py:96, in link_iter(coords_iter, search_range, **kwargs)
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=93'>94</a> # initialize the linker and yield the particle ids of the first frame
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=94'>95</a> linker = Linker(search_range, **kwargs)
# ---> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=95'>96</a> linker.init_level(coords, t)
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=96'>97</a> yield t, linker.particle_ids
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=98'>99</a> for t, coords in coords_iter:
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\linking.py:470, in Linker.init_level(self, coords, t, extra_data)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=466'>467</a> for j in range(self.memory):
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=467'>468</a>     self.mem_history.append(set())
# --> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=469'>470</a> self.update_hash(coords, t, extra_data)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=470'>471</a> # Assume everything in first level starts a Track.
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=471'>472</a> # Iterate over prev_level, not prev_set, because order -> track ID.
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=472'>473</a> for p in self.hash.points:
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\linking.py:455, in Linker.update_hash(self, coords, t, extra_data)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=451'>452</a> if prev_hash is not None and self.predictor is not None:
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=452'>453</a>     prev_hash.set_predictor(self.predictor, t)  # Rewrite positions
# --> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=454'>455</a> self.hash = self.hash_cls(points_from_arr(coords, t, extra_data),
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=455'>456</a>                           ndim=self.ndim, to_eucl=self.to_eucl,
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=456'>457</a>                           dist_func=self.dist_func)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/linking.py?line=457'>458</a> return prev_hash
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\utils.py:26, in points_from_arr(coords, frame_no, extra_data)
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=23'>24</a> """ Convert an ndarray of coordinates to a list of PointFindLink """
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=24'>25</a> if extra_data is None:
# ---> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=25'>26</a>     return [Point(frame_no, pos) for pos in coords]
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=26'>27</a> else:
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=27'>28</a>     return [Point(frame_no, pos, extra_data={key: extra_data[key][i]
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=28'>29</a>                                              for key in extra_data})
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=29'>30</a>             for i, pos in enumerate(coords)]
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\utils.py:26, in <listcomp>(.0)
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=23'>24</a> """ Convert an ndarray of coordinates to a list of PointFindLink """
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=24'>25</a> if extra_data is None:
# ---> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=25'>26</a>     return [Point(frame_no, pos) for pos in coords]
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=26'>27</a> else:
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=27'>28</a>     return [Point(frame_no, pos, extra_data={key: extra_data[key][i]
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=28'>29</a>                                              for key in extra_data})
#      <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=29'>30</a>             for i, pos in enumerate(coords)]
#
# File c:\bin\python\anaconda64\envs\picasso\lib\site-packages\trackpy\linking\utils.py:112, in Point.__init__(self, t, pos, id, extra_data)
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=109'>110</a> def __init__(self, t, pos, id=None, extra_data=None):
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=110'>111</a>     self._track = None
# --> <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=111'>112</a>     self.uuid = next(self.counter)         # unique id for __hash__
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=112'>113</a>     self.t = t
#     <a href='file:///c%3A/bin/python/anaconda64/envs/picasso/lib/site-packages/trackpy/linking/utils.py?line=113'>114</a>     self.pos = np.asarray(pos)
#
# AttributeError: 'Point' object has no attribute 'counter'
